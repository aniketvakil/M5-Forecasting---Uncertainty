# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/topsubmis/107.csv
# /kaggle/input/topsubmis/12.csv
# /kaggle/input/topsubmis/108.csv
# /kaggle/input/top-submmm/submissionUncertainty1.csv
# /kaggle/input/top-submmm/submissionUncertainty.csv
# /kaggle/input/top-submmm/submission (3).csv
# /kaggle/input/top-submmm/submission (5).csv
# /kaggle/input/top-submmm/submission (4).csv
# /kaggle/input/top-submmm/submission (1).csv
# /kaggle/input/top-submmm/submission.csv
# /kaggle/input/top-submmm/submissionUncertaintyDay1500.csv
# /kaggle/input/top-submmm/submission (1) (1).csv
# /kaggle/input/top-submmm/submission (2) (1).csv
# /kaggle/input/top-submmm/submission (3) (1).csv
# /kaggle/input/top-submmm/submission (8).csv
# /kaggle/input/top-submmm/submission (2).csv
# /kaggle/input/top-submmm/submission (6).csv
# /kaggle/input/top-submmm/submission (7).csv
# /kaggle/input/m5-forecasting-uncertainty/sample_submission.csv
# /kaggle/input/m5-forecasting-uncertainty/sales_train_validation.csv
# ...

# %%
submission1 = pd.read_csv('../input/top-submmm/submission.csv')
submission2 = pd.read_csv('../input/top-submmm/submissionUncertaintyDay1500.csv')
submission3 = pd.read_csv('../input/top-submmm/submission (1).csv')
submission4 = pd.read_csv('../input/top-submmm/submission (2).csv')
submission5 = pd.read_csv('../input/top-submmm/submission (3) (1).csv')
submission6 = pd.read_csv('../input/top-submmm/submission (3).csv')
submission7 = pd.read_csv('../input/top-submmm/submission (4).csv')
submission8 = pd.read_csv('../input/top-submmm/submission (5).csv')
submission9 = pd.read_csv('../input/top-submmm/submission (6).csv')
submission10 = pd.read_csv('../input/top-submmm/submission (7).csv')
submission11 = pd.read_csv('../input/top-submmm/submission (8).csv')
submission12 = pd.read_csv('../input/top-submmm/submissionUncertainty.csv')
#submission13 = pd.read_csv('../input/top-submmm/submissionUncertainty1.csv')

# %%
submission1.head()
# Out:
#                             id           F1           F2           F3  \
# 0  CA_1_FOODS_0.005_evaluation  1814.470805  1521.393240  1557.995615
# 1  CA_1_FOODS_0.005_validation  1680.175555  1491.105245  1400.191095
# 2  CA_1_FOODS_0.025_evaluation  2809.403675  2403.766300  2408.640210
# 3  CA_1_FOODS_0.025_validation  2580.183655  2298.021840  2223.237805
# 4  CA_1_FOODS_0.165_evaluation  2906.256995  2484.011595  2521.822910
#
#             F4           F5          F6           F7           F8  \
# 0  1497.942980  1550.994040  2001.75607  2131.657985  1919.345845
# 1  1438.458410  1660.721045  2207.65346  2226.497155  1824.799750
# 2  2358.458785  2637.296390  3341.11061  3537.033985  3213.538540
# 3  2272.108725  2687.961885  3544.42930  3774.805900  2897.615575
# 4  2444.463360  2715.306870  3466.10291  3833.825790  3420.587985
#
#             F9  ...          F19          F20          F21          F22  \
# ...

# %%
submission1 = submission1.sort_values(by = 'id').reset_index(drop = True)
submission2  = submission2.sort_values(by = 'id').reset_index(drop = True)
submission3 = submission3.sort_values(by = 'id').reset_index(drop = True)
submission4 = submission1.sort_values(by = 'id').reset_index(drop = True)
submission5  = submission2.sort_values(by = 'id').reset_index(drop = True)
submission6 = submission3.sort_values(by = 'id').reset_index(drop = True)
submission7 = submission1.sort_values(by = 'id').reset_index(drop = True)
submission8  = submission2.sort_values(by = 'id').reset_index(drop = True)
submission9 = submission3.sort_values(by = 'id').reset_index(drop = True)
submission10 = submission1.sort_values(by = 'id').reset_index(drop = True)
submission11  = submission2.sort_values(by = 'id').reset_index(drop = True)
submission12 = submission3.sort_values(by = 'id').reset_index(drop = True)

sub5 = submission1.copy()

for i in sub5.columns :
    if i != 'id' :
        sub5[i] = 0.1*submission1[i] + 0.1*submission2[i]+0.1*submission3[i]+0.1*submission4[i] + 0.1*submission5[i]+0.1*submission6[i]+0.05*submission7[i] + 0.05*submission8[i]+0.05*submission9[i]+0.05*submission10[i] + 0.1*submission11[i]+0.1*submission12[i]
        
sub5.to_csv('submission.csv', index = False)

# %%
sub5.head()
# Out:
#                             id           F1           F2           F3  \
# 0  CA_1_FOODS_0.005_evaluation  1374.010992  1167.964542  1282.050285
# 1  CA_1_FOODS_0.005_validation  1304.308172  1199.381439  1146.885178
# 2  CA_1_FOODS_0.025_evaluation  2649.272043  2259.967260  2383.344758
# 3  CA_1_FOODS_0.025_validation  2503.211301  2269.345507  2184.894391
# 4  CA_1_FOODS_0.165_evaluation  2823.953029  2382.629584  2516.135648
#
#             F4           F5           F6           F7           F8  \
# 0  1215.708244  1277.962232  1601.057716  1772.038771  1593.438553
# 1  1125.396143  1320.539109  1859.148128  1878.990517  1441.823975
# 2  2326.805041  2577.657692  3243.892608  3563.946336  3140.636767
# 3  2181.706227  2606.937420  3538.899300  3775.578175  2786.105172
# 4  2429.746378  2778.720941  3486.566038  3866.337542  3416.845936
#
#             F9  ...          F19          F20          F21          F22  \
# ...
